# %% [markdown]
# # Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
# your code here

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
# your code here
import json
import urllib
import requests
import pandas as pd
from pandas import json_normalize

url='https://www.zalando.fr/api/catalog/articles?categories=promo-femme&limit=84&offset=84&sort=popularity'

# %%
# Your code
response = urllib.request.urlopen(url)
results = json.load(response)

flattened_data = json_normalize(results)
flattened_data1 = json_normalize(flattened_data.articles[0])
flattened_data1.head()
# Out:
#              sku                                               name  \
# 0  NI111S06B-Q11  INTERNATIONALIST - Baskets basses - black/summ...
# 1  MJ331F00T-Q11         LASH SENSATIONAL MASCARA - Mascara - black
# 2  ON321U00A-Q11            SEDONA OTW NOOS - Manteau court - black
# 3  PE121N028-K16                           VENUS - Jean droit - h06
# 4  MK151H03O-O12  JET SET TRAVEL CROSSBODY - Sac bandoulière - b...
#
#                                                sizes  \
# 0  [35.5, 36, 36.5, 37.5, 38, 38.5, 39, 40, 40.5,...
# 1                                                 []
# 2                                  [XS, S, M, L, XL]
# 3  [24x30, 24x32, 25x30, 25x32, 25x34, 26x30, 26x...
# 4                                         [One Size]
#
#                                              url_key  \
# 0  nike-sportswear-internationalist-baskets-basse...
# 1  maybelline-lash-sensational-black-pearl-mascar...
# 2         only-onlsedona-manteau-court-on321u00a-q11
# 3          pepe-jeans-venus-jean-droit-pe121n028-k16
# 4  michael-michael-kors-jet-set-sac-bandouliere-m...
#
#                                                media            brand_name  \
# 0  [{'path': 'spp-media-p1/f9989c9dca9132e9bb14c7...       Nike Sportswear
# 1  [{'path': 'spp-media-p1/a00fb82db25f3f979fcb3d...   Maybelline New York
# 2  [{'path': 'spp-media-p1/9d8b2792671c386eb849b6...                  ONLY
# 3  [{'path': 'spp-media-p1/62eabed3c8563ee79c3c80...            Pepe Jeans
# 4  [{'path': 'spp-media-p1/5bbfce2990bf3d5882e608...  MICHAEL Michael Kors
#
#    is_premium family_articles  \
# 0       False              []
# 1       False              []
# 2       False              []
# 3       False              []
# 4        True              []
#
#                                                flags product_group  \
# 0  [{'key': 'discountRate', 'value': '-10%', 'tra...          shoe
# 1  [{'key': 'discountRate', 'value': '-10%', 'tra...        beauty
# 2  [{'key': 'discountRate', 'value': 'Jusqu’à -15...      clothing
# 3  [{'key': 'discountRate', 'value': 'Jusqu’à -30...      clothing
# 4  [{'key': 'discountRate', 'value': '-30%', 'tra...   accessoires
#
#   delivery_promises price.original price.promotional  \
# 0                []        89,95 €           80,95 €
# 1                []         9,95 €            8,95 €
# 2                []        49,99 €           42,49 €
# 3                []        99,95 €           69,95 €
# 4                []       194,95 €          136,95 €
#
#    price.has_different_prices  price.has_different_original_prices  \
# 0                       False                                False
# 1                       False                                False
# 2                        True                                False
# 3                        True                                False
# 4                       False                                False
#
#    price.has_different_promotional_prices  \
# 0                                   False
# 1                                   False
# 2                                    True
# 3                                    True
# 4                                   False
#
#    price.has_discount_on_selected_sizes_only  amount  price.base_price outfits
# 0                                      False     NaN               NaN     NaN
# 1                                      False  9,5 ml  94,21 € / 100 ml     NaN
# 2                                      False     NaN               NaN     NaN
# 3                                      False     NaN               NaN     NaN
# 4                                      False     NaN               NaN     NaN

# %%
total_pages=results['pagination']['page_count']
df=pd.DataFrame()
for i in range(50):
    k=84*i
    url=f'https://www.zalando.fr/api/catalog/articles?categories=promo-femme&limit=84&offset={k}&sort=popularity'
    response = urllib.request.urlopen(url)
    results = json.load(response)
    flattened_data = json_normalize(results)
    flattened_data1 = json_normalize(flattened_data.articles[0])
    flattened_data1=flattened_data1.set_index('sku')
    df = df.append(flattened_data1)
    print(f"getting page {i} of {total_pages}", end='\r')

df.head()


# He puesto 50 pags en vez de todas, porque nunca se completaba
# Out:
# getting page 49 of 892
#                                                             name  \
# sku
# AD111A0Q7-A11  STAN SMITH - Baskets basses - footwear white/g...
# LE221N04U-Q11  MILE HIGH SUPER SKINNY - Jeans Skinny - black ...
# LE221G031-K11  ORIGINAL TRUCKER - Veste en jean - soft as but...
# AN611BA4P-Q11                     Escarpins à plateforme - black
# VA211S03A-Q11       UA OLD SKOOL  - Baskets basses - black/white
#
#                                                            sizes  \
# sku
# AD111A0Q7-A11  [36, 38, 40, 42, 36 2/3, 37 1/3, 38 2/3, 39 1/...
# LE221N04U-Q11  [23x28, 23x30, 24x28, 24x30, 24x32, 25x28, 25x...
# LE221G031-K11                                 [XXS, XS, S, M, L]
# AN611BA4P-Q11                           [36, 37, 38, 39, 40, 41]
# VA211S03A-Q11  [36, 36.5, 37, 38, 38.5, 39, 40, 40.5, 41, 42,...
#
#                                                          url_key  \
# sku
# AD111A0Q7-A11  adidas-originals-stan-smith-baskets-basses-foo...
# LE221N04U-Q11  levisr-mile-high-super-skinny-jeans-skinny-le2...
# LE221G031-K11  levisr-original-trucker-veste-en-jean-soft-as-...
# AN611BA4P-Q11  anna-field-escarpins-compenses-black-an611ba4p...
# VA211S03A-Q11       vans-baskets-basses-blackwhite-va211s03a-q11
#
#                                                            media  \
# sku
# AD111A0Q7-A11  [{'path': 'spp-media-p1/566391dd3ffb3feca398e7...
# LE221N04U-Q11  [{'path': 'spp-media-p1/df7d6a01a4833214aa11c6...
# LE221G031-K11  [{'path': 'spp-media-p1/b06b79cb3ac83c549f3008...
# AN611BA4P-Q11  [{'path': 'spp-media-p1/a00b49ce7d93303c86891e...
# VA211S03A-Q11  [{'path': 'spp-media-p1/ff31fe540dca3d898deafc...
#
#                      brand_name  is_premium family_articles  \
# sku
# AD111A0Q7-A11  adidas Originals       False              []
# LE221N04U-Q11           Levi's®       False              []
# LE221G031-K11           Levi's®       False              []
# AN611BA4P-Q11        Anna Field       False              []
# VA211S03A-Q11              Vans       False              []
#
#                                                            flags  \
# sku
# AD111A0Q7-A11  [{'key': 'discountRate', 'value': 'Jusqu’à -25...
# LE221N04U-Q11  [{'key': 'discountRate', 'value': '-30%', 'tra...
# LE221G031-K11  [{'key': 'discountRate', 'value': '-30%', 'tra...
# AN611BA4P-Q11  [{'key': 'discountRate', 'value': '-15%', 'tra...
# VA211S03A-Q11  [{'key': 'discountRate', 'value': '-10%', 'tra...
#
#               product_group delivery_promises price.original  \
# sku
# AD111A0Q7-A11          shoe                []        99,95 €
# LE221N04U-Q11      clothing                []        99,95 €
# LE221G031-K11      clothing                []       119,95 €
# AN611BA4P-Q11          shoe                []        34,99 €
# VA211S03A-Q11          shoe                []        84,95 €
#
#               price.promotional  price.has_different_prices  \
# sku
# AD111A0Q7-A11           74,95 €                        True
# LE221N04U-Q11           69,95 €                       False
# LE221G031-K11           83,95 €                       False
# AN611BA4P-Q11           29,69 €                       False
# VA211S03A-Q11           76,45 €                       False
#
#                price.has_different_original_prices  \
# sku
# AD111A0Q7-A11                                False
# LE221N04U-Q11                                False
# LE221G031-K11                                False
# AN611BA4P-Q11                                False
# VA211S03A-Q11                                False
#
#                price.has_different_promotional_prices  \
# sku
# AD111A0Q7-A11                                    True
# LE221N04U-Q11                                   False
# LE221G031-K11                                   False
# AN611BA4P-Q11                                   False
# VA211S03A-Q11                                   False
#
#                price.has_discount_on_selected_sizes_only  \
# sku
# AD111A0Q7-A11                                      False
# LE221N04U-Q11                                      False
# LE221G031-K11                                      False
# AN611BA4P-Q11                                      False
# VA211S03A-Q11                                      False
#
#                                                          outfits amount  \
# sku
# AD111A0Q7-A11                                                NaN    NaN
# LE221N04U-Q11                                                NaN    NaN
# LE221G031-K11                                                NaN    NaN
# AN611BA4P-Q11                                                NaN    NaN
# VA211S03A-Q11  [{'id': 'Fjt8J_KKSKq', 'url_key': '/outfits/Fj...    NaN
#
#               price.base_price
# sku
# AD111A0Q7-A11              NaN
# LE221N04U-Q11              NaN
# LE221G031-K11              NaN
# AN611BA4P-Q11              NaN
# VA211S03A-Q11              NaN

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
# your code here
df.brand_name.value_counts().index[0]
# Out:
# 'Anna Field'

# %%
df['price.original']=df['price.original'].str.extract('(\d*,\d*)')
df['price.promotional']=df['price.promotional'].str.extract('(\d*,\d*)')

df['price.original'] = [x.replace(',', '.') for x in df['price.original']]
df['price.promotional'] = [x.replace(',', '.') for x in df['price.promotional']]

# %%
df['discount_amount']=df['price.original'].astype(float)-df['price.promotional'].astype(float)
df1=df.copy()

# %%
total_disc=df1.groupby(['brand_name']).sum().discount_amount

# %%
total_disc.sort_values(ascending=False).index[0]
# Out:
# 'Silvio Tossi'

# %%
total_disc_sum=df['discount_amount'].sum()
original_sum=df['price.original'].astype(float).sum()
discountsum=(total_disc_sum/original_sum)
discountsum
# Out:
# 0.29013954482437804

# %%
t=df[['price.original','discount_amount']]
t
# Out:
#               price.original  discount_amount
# sku
# AD111A0Q7-A11          99.95            25.00
# LE221N04U-Q11          99.95            30.00
# LE221G031-K11         119.95            36.00
# AN611BA4P-Q11          34.99             5.30
# VA211S03A-Q11          84.95             8.50
# ...                      ...              ...
# CO411A190-A11         109.95            11.00
# L0U21N03X-K12          54.99            21.80
# PO221E06B-K12          99.95            25.00
# GL921C0LH-G11          42.99             6.30
# PE111S01U-A11          49.90            14.97
#
# [4200 rows x 2 columns]
